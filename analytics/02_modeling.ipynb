# %% [markdown]
# # Module 2 Predictive modeling
#
# Student starter notebook. Run cells in order. TODO sections are unfinished
# assignment work; setup success is not a completed capstone.

# %%
from pathlib import Path
import sys
from importlib.metadata import version, PackageNotFoundError

ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents]
            if (p / "SUBMISSION_CHECKLIST.md").exists())
print("Python:", sys.version.split()[0])
print("Kernel:", Path(sys.executable).parent.name)
print("Project:", ROOT.name)

def show_versions(packages):
    for package in packages:
        try:
            print(f"{package}: {version(package)}")
        except PackageNotFoundError:
            print(f"{package}: missing (needed for full implementation)")

# %%
show_versions(["pandas", "scikit-learn", "imbalanced-learn", "joblib"])
import pandas as pd
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression

MODULE = ROOT / "analytics"
CSV_PATH = MODULE / "titanic.csv"
raw = pd.read_csv(CSV_PATH) if CSV_PATH.exists() else None
print("Raw data ready" if raw is not None else "Run EDA's first download before modeling.")

# %% [markdown]
# ## 1 Split before learned preprocessing
# TODO: Apply justified deterministic row/column decisions to the same source data; perform a stratified train/test split.
# Exclude target leakage (alive duplicates survived), redundant flags and any full-data EDA imputations. Use one identical split for all classifiers.

# %%
NUMERIC = ["pclass", "age", "sibsp", "parch", "fare"]
CATEGORICAL = ["sex", "embarked"]

def make_preprocessor():
    numeric = Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler()),
    ])
    categorical = Pipeline([
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("encoder", OneHotEncoder(handle_unknown="ignore", sparse_output=False)),
    ])
    return ColumnTransformer([
        ("numeric", numeric, NUMERIC),
        ("categorical", categorical, CATEGORICAL),
    ])

baseline = Pipeline([
    ("preprocessor", make_preprocessor()),
    ("model", LogisticRegression(max_iter=1000, random_state=42)),
])
print("Unfitted baseline pipeline ready. Fit only on X_train, y_train.")

# %% [markdown]
# ## 2 Three classifiers
# TODO: Fit Logistic Regression, Decision Tree and Random Forest. Draw a labeled decision tree.
# Use identical held-out rows and never fit preprocessing on test data.

# %%
# TODO: Split, train and evaluate all three full pipelines.

# %% [markdown]
# ## 3 Evaluation
# TODO: Confusion matrices, accuracy, precision, recall, F1, ROC curves/AUC and side-by-side classifier table.

# %%
# TODO: Save real evaluation values; do not select models based only on training accuracy.

# %% [markdown]
# ## 4 Imbalance and tuning
# TODO: Compare baseline, balanced class weights and SMOTE with precision/recall/F1.
# Use an imbalanced-learn pipeline so resampling happens inside training folds only.
# GridSearchCV must tune Random Forest n_estimators, max_depth, max_features and report best params and OOB score (oob_score=True).

# %%
# TODO: Implement fold-safe imbalance comparisons and grid search.

# %% [markdown]
# ## 5 Fare regression
# TODO: Predict fare using other appropriate features (exclude fare from inputs). Report MAE, RMSE, R2, adjusted R2;
# plot residuals and state whether their spread suggests heteroscedasticity. Use transformed feature count for adjusted R2 and check its denominator.

# %%
# TODO: Use a separate regression preprocessing pipeline; fit only on regression training rows.

# %% [markdown]
# ## 6 Recommendation and saved pipeline
# TODO: Separate classifier and regression metric groups. Write a 3-5 sentence recommendation using actual results.
# Save the complete fitted best pipeline with joblib, reload it and compare predictions on raw input.

# %%
# TODO: joblib.dump(full_pipeline, MODULE / "models" / "best_pipeline.joblib")
